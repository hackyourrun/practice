# %%
import pandas as pd

# %%
url = "http://steamtownmarathon.com/wp-content/uploads/2019/10/Steamtown-Final-Report-10-16-19-Update.xls"
timedelta_cols = ['18 MILE SPLIT', 'CHIP TIME', 'GUN TIME', 'GUN PACE']
df = pd.read_excel(url, converters={col:str for col in timedelta_cols})

# %%
for col in timedelta_cols:
    df[col] = pd.to_timedelta(df[col])

# %%
df['18_mile_pace'] = pd.Series(df['18 MILE SPLIT'] / 18)  # makes a new column with pace for 18 miles 
df['last_8.2_mile_pace'] = pd.Series((df['CHIP TIME'] - df['18 MILE SPLIT'])/8.2)  # makes a new column with pace for rest of race
df['change_in_pace'] = pd.Series(abs(df['18_mile_pace'] - df['last_8.2_mile_pace']))  # makes a new column for difference in pace

# %%
df.sort_values('change_in_pace') #sorts based on change in pace from the split
# Out:
#       PLACE RACE_NAME   BIB  BRACKET FIRST_NAME       LAST_NAME GENDER  AGE  \
# 116     113  Marathon   407  M 30-34     Jordan       Greenberg      M   30
# 660     657  Marathon   353  F 25-29   Cara Ann       Frankosky      F   29
# 112     109  Marathon   904  M 55-59    Michael        green sr      M   58
# 649     646  Marathon  1056  M 30-34     Justin        Zalewski      M   30
# 178     175  Marathon   293  M 40-44    Gregory          Durcik      M   40
# ...     ...       ...   ...      ...        ...             ...    ...  ...
# 1005   1002  Marathon  1074  M 30-34    roberto         cabrera      M   30
# 168     165  Marathon   110  M 40-44      Jason          Bobber      M   44
# 529     526  Marathon  1031  F 45-49   Kristina  Wilhelm-Nelson      F   47
# 662     659  Marathon   862  F 30-34  Elizabeth        Schaefer      F   34
# 731     728  Marathon   759  F 30-34    Justine          paduck      F   32
#
# ...

# %%
# df.plot(y='CHIP TIME', grid=True, figsize=(20,10))
# df.plot('CHIP TIME', grid=True, figsize=(20,10))
df.plot('PLACE', grid=True, figsize=(20,10))
# df.plot(figsize=(20,10))
